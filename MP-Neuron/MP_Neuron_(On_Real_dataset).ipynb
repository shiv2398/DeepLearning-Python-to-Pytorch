# %%
import sklearn.datasets
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
breast_cancer=sklearn.datasets.load_breast_cancer()

# %%
X=breast_cancer.data
Y=breast_cancer.target
X.shape,Y.shape
# Out:
# ((569, 30), (569,))

# %%
data=pd.DataFrame(breast_cancer.data,columns=breast_cancer.feature_names)

# %%
data['class']=breast_cancer.target

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  class
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension       class
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
print(data['class'].value_counts())
# Out:
# 1    357
# 0    212
# Name: class, dtype: int64

# %%
print(breast_cancer.target_names)
# Out:
# ['malignant' 'benign']

# %%
data.groupby('class').mean()
# Out:
#        mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# class
# 0        17.462830     21.604906      115.365377  978.376415         0.102898
# 1        12.146524     17.914762       78.075406  462.790196         0.092478
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# class
# 0              0.145188        0.160775             0.087990       0.192909
# 1              0.080085        0.046058             0.025717       0.174186
#
#        mean fractal dimension  ...  worst radius  worst texture  \
# class                          ...
# 0                    0.062680  ...     21.134811      29.318208
# 1                    0.062867  ...     13.379801      23.515070
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# class
# 0           141.370330  1422.286321          0.144845           0.374824
# 1            87.005938   558.899440          0.124959           0.182673
#
#        worst concavity  worst concave points  worst symmetry  \
# class
# 0             0.450606              0.182237        0.323468
# 1             0.166238              0.074444        0.270246
#
#        worst fractal dimension
# class
# 0                     0.091530
# 1                     0.079442
#
# [2 rows x 30 columns]

# %%
X=data.drop('class',axis=1)
Y=data['class']

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Train Test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1,stratify=Y)

# %%
print(x_train.mean(),x_test.mean())
# Out:
# mean radius                 14.128668
# mean texture                19.358125
# mean perimeter              92.000547
# mean area                  656.445313
# mean smoothness              0.096339
# mean compactness             0.104756
# mean concavity               0.089705
# mean concave points          0.049221
# mean symmetry                0.181368
# mean fractal dimension       0.062836
# radius error                 0.408173
# texture error                1.228052
# perimeter error              2.895233
# area error                  40.764039
# smoothness error             0.007023
# compactness error            0.025371
# concavity error              0.032004
# concave points error         0.011794
# symmetry error               0.020632
# fractal dimension error      0.003772
# worst radius                16.278430
# worst texture               25.771211
# worst perimeter            107.367852
# worst area                 883.982813
# worst smoothness             0.132326
# worst compactness            0.255434
# worst concavity              0.274336
# worst concave points         0.115059
# worst symmetry               0.290685
# worst fractal dimension      0.084035
# dtype: float64 mean radius                 14.114930
# mean texture                18.674561
# mean perimeter              91.685965
# mean area                  640.910526
# mean smoothness              0.096555
# mean compactness             0.100611
# mean concavity               0.080661
# mean concave points          0.046205
# mean symmetry                0.179309
# mean fractal dimension       0.062455
# radius error                 0.378218
# texture error                1.116260
# perimeter error              2.604011
# area error                  36.501930
# smoothness error             0.007204
# compactness error            0.026436
# concavity error              0.030901
# concave points error         0.011817
# symmetry error               0.019741
# fractal dimension error      0.004001
# worst radius                16.186193
# worst texture               24.832982
# worst perimeter            106.303333
# worst area                 850.045614
# worst smoothness             0.132748
# worst compactness            0.243761
# worst concavity              0.252897
# worst concave points         0.110539
# worst symmetry               0.284602
# worst fractal dimension      0.083141
# dtype: float64

# %% [markdown]
# # Binarisation of input

# %%
import matplotlib.pyplot as plt 
plt.plot(x_test.T,'*')
plt.xticks(rotation='vertical')
plt.show()

# %%
X_binarised_train = x_train.apply(pd.cut, bins=2, labels=[1,0])

# %%
X_binarised_test = x_test.apply(pd.cut, bins=2, labels=[1,0])

# %%
X_binarised_test = X_binarised_test.values
X_binarised_train = X_binarised_train.values

# %% [markdown]
# # MP Neuron Model

# %%
from random import randint

# %%
b=3
i=randint(0,X_binarised_train.shape[0])
print('foe row',i)
if (np.sum(X_binarised_train[100,:])>=b):
    print('MP Neuron inference is malignant')
else:
    print('MP Neuron inference is benign')
if (y_train[i]==1):
    print('Ground truth is malignant')
else:
    print('Ground truth is benign')
# Out:
# foe row 234
# MP Neuron inference is malignant
# Ground truth is malignant

# %%
b=3 
y_pred_train=[]
accurate_rows=0
for x,y in zip(X_binarised_train,y_train):
    y_pred=(np.sum(x)>=b)
    y_pred_train.append(y_pred)
    accurate_rows+=(y==y_pred)
print(accurate_rows,accurate_rows/X_binarised_train.shape[0])
# Out:
# 321 0.626953125

# %%
for b in range(X_binarised_train.shape[1] + 1):
  y_pred_train = []
  accurate_rows = 0

  for x, y in zip(X_binarised_train, y_train):
    y_pred = (np.sum(x) >= b)
    Y_pred_train.append(y_pred)
    accurate_rows += (y == y_pred)

  print(b, accurate_rows/X_binarised_train.shape[0])
# Out:
# 0 0.626953125
# 1 0.626953125
# 2 0.626953125
# 3 0.626953125
# 4 0.626953125
# 5 0.626953125
# 6 0.626953125
# 7 0.626953125
# 8 0.626953125
# 9 0.626953125
# 10 0.626953125
# 11 0.626953125
# 12 0.626953125
# 13 0.62890625
# 14 0.6328125
# 15 0.634765625
# 16 0.64453125
# 17 0.65234375
# 18 0.662109375
# 19 0.666015625
# 20 0.677734375
# 21 0.69140625
# 22 0.708984375
# 23 0.734375
# 24 0.7734375
# 25 0.8046875
# 26 0.83203125
# 27 0.8515625
# 28 0.84375
# 29 0.806640625
# 30 0.728515625

# %%
from sklearn.metrics import accuracy_score

# %%
b=28
y_pred_test=[]
for x in X_binarised_test:
    y_pred=(np.sum(x)>=b)
    y_pred_test.append(y_pred)
accuracy=accuracy_score(y_pred_test,y_test)
print(b,accuracy)
# Out:
# 28 0.6140350877192983

# %%
class MPNeuron:
    def __init__(self):
        self.b=None
        
    def model(self,x):
        return (sum(x)>=self.b)
    
    def predict(self,X):
        y=[]
        for x in X:
            result=self.model(x)
            y.append(result)
        return np.array(y)
    def fit(self,X,Y):
        
        accuracy={}
        
        for b in range(X.shape[1]+1):
            self.b=b
            y_pred=self.predict(X)
            accuracy[b]=accuracy_score(y_pred,Y)
            
        best_b=max(accuracy,key=accuracy.get)
        self.b=best_b
        
        print('Optimal values of b is ',best_b)
        print('Highest accuracy is ',accuracy[best_b])

# %%
mp_neuron=MPNeuron()
mp_neuron.fit(X_binarised_train,y_train)
# Out:
# Optimal values of b is  27
# Highest accuracy is  0.8515625

# %%
Y_test_pred=mp_neuron.predict(X_binarised_test)
accuracy_test=accuracy_score(Y_test_pred,y_test)

# %%
print(accuracy_test)
# Out:
# 0.7543859649122807
